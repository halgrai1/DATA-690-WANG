# %% [markdown]
# # Assignment 1
# *Practicing Python Code in Chapter 2*
#
# **Author**: Hala Algrain
#
# **Date**: 1.31.2021

# %% [markdown]
# ## Book Section 2.1 - 2.2

# %% [markdown]
# ### First Line of Code

# %%
print('Hello world')
# Out:
# Hello world

# %% [markdown]
# ### Troubleshooting
# *making sure that the most up to date version of python is running*

# %%
from platform import python_version

print(python_version())
# Out:
# 3.7.9

# %% [markdown]
# ### Tab Completion

# %%
# as soon as a variable is autocompletion drops down
an_apple = 27
an_example = 42
# typing "an" in Jupyter a dropdown menu of suggestions automatically pops up
b = [1,2,3]
# typing "b." drops down methods and attributes on the object
import datetime
# also works with modules like "datetime."
# clicking tab allows you to select the option

# %% [markdown]
# ### Introspection

# %%
# Using ? before or after a variable will display some general information
b = [1,2,3]
print(b)
b?
# ? not working on Jupyter
# google: help function works instead of ?
help(b)
help(print)
# Out:
# [1, 2, 3]
# Help on list object:
#
# class list(object)
#  |  list(iterable=(), /)
#  |
#  |  Built-in mutable sequence.
#  |
#  |  If no argument is given, the constructor creates a new empty list.
#  |  The argument must be an iterable if specified.
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return key in self.
#  |
#  |  __delitem__(self, key, /)
#  |      Delete self[key].
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __getitem__(...)
#  |      x.__getitem__(y) <==> x[y]
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __iadd__(self, value, /)
#  |      Implement self+=value.
#  |
#  |  __imul__(self, value, /)
#  |      Implement self*=value.
#  |
# ...

# %% [markdown]
# ### %run Command

# %%
#created a new python program filed called python_script_test.py
# def f(x, y, z):
#    return (x + y) / z
## troubleshooting "f" can be any variable name: `def` my_function():
# a = 1
# b = 2
# c = 3
# result = f(a, b, c)
# print(result)
# %run python_script_test.py
# %load python_script_test.py
# can't get %load to run even after troubleshooting
# where is it being copied?
# Out:
# 1.0

# %% [markdown]
# ### Practicing Shortcuts
# - Ctrl-P or up-arrow Search backward in command history for commands starting with currently entered text
# - Ctrl-N or down-arrow Search forward in command history for commands starting with currently entered text
# - Ctrl-R Readline-style reverse history search (partial matching)
# - Ctrl-Shift-V Paste text from clipboard
# - Ctrl-C Interrupt currently executing code
# - Ctrl-A Move cursor to beginning of line
# - Ctrl-E Move cursor to end of line
# - Ctrl-K Delete text from cursor until end of line
# - Ctrl-U Discard all text on current line
# - Ctrl-F Move cursor forward one character
# - Ctrl-B Move cursor back one character
# - Ctrl-L Clear screen

# %% [markdown]
# ### About Magic Commands

# %%
import numpy as np
# troubleshooting 'np not defined' added previous line
a = np.random.randn(100, 100)
# %timeit np.dot(a, a)
# %pwd
# magix fx can be used without % and defined as a variable
foo = %pwd
foo
# Out:
# 148 µs ± 17.3 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# '/work'

# %% [markdown]
# ### Matplotlib Integration

# %%
# %matplotlib
# %matplotlib inline
# Out:
# Using matplotlib backend: agg

# %% [markdown]
# ## Book Section 2.3

# %% [markdown]
# ### Language Semantics
# - white space i.e. indentation is important for Python
# - Semicolons can be used to separate multiple statements on a single line
# - everything is an object
#     - Each object has an associated type (e.g., string or function)

# %%
# creating two references for the same object
a = [1, 2, 3]
b = a
print(b)
a.append(4)
print(b)
# Out:
# [1, 2, 3]
# [1, 2, 3, 4]

# %%
# passing objects as arguments to a function
def append_element(some_list, element):
    some_list.append(element)
data = [1, 2, 3]
print(data)
append_element(data, 4)
print(data)
# Out:
# [1, 2, 3]
# [1, 2, 3, 4]

# %%
# object references in Python have no type associated with them
a=5
type(a)
b= 'foo'
type(b)
# checking varaiable type
isinstance(a, int)
# Out:
# True

# %% [markdown]
# ### Imports
# *accessing  the variables and functions in another file in the same directory*

# %%
# created some_module.py
import some_module
result = some_module.f(5)
pi = some_module.PI
print(result)
# alternative way
from some_module import f, g, PI
result = g(5, PI)
# as keyword you can give imports different variable names
import some_module as sm
from some_module import PI as pi, g as gf
r1 = sm.f(pi)
r2 = gf(6, pi)
# Out:
# 7

# %% [markdown]
# ### Binary Operators and Comparisons

# %%
5-7
12 + 21.5
5 <= 2
a = [1, 2, 3]
b = a
c = list(a)
a is b
a is not c
a is c
# comparing with is is not the same as the == operator
a == c
# Out:
# True

# %% [markdown]
# ### Immutability of objects
# - lists, dicts, NumPy arrays, and most user-defined types (classes), are mutable
# - strings and tuples, are immutable
# - Remember that just because you can mutate an object does not mean that you always
# should. Such actions are known as side effects.

# %%
a_list = ['foo', 2, [4, 5]]
print(a_list)
a_list[2] = (3, 4)
print(a_list)
# Out:
# ['foo', 2, [4, 5]]
# ['foo', 2, (3, 4)]

# %% [markdown]
# ### Scalar Types
# *Screenshot from Book*
# ![Standard Python Scalar Types Table](https://i.imgur.com/Tei5ArC.png)

# %%
# Numeric primary Python types for numbers are int and float
ival = 17239871
ival = ival ** 6
print(ival) #int can store arbitrarily large numbers
# float can be expressed with scientific notation
fval2 = 6.78e-5
print(fval2)
3/2 #Integer division resulting in a fraction yields a floating-point number
3//2 # C-style drops integer using //
# Out:
# 26254519291092456596965462913230729701102721
# 6.78e-05
# 1

# %% [markdown]
# ### String
# - Python strings are immutable; you cannot modify a string:
#     - In: `a = 'this is a string'`
#     - In: `a[10] = 'f'`
#     - Out: TypeError: 'str' object does not support item assignment

# %%
# string literals using either single quotes '' or double quotes ""
a = 'one way of writing a string'
b = "another way"
print(a)
print(b)
# multiline strings with line breaks, you can use triple quotes, either ''' or """
c = """
This is a longer string that
spans multiple lines
"""
print(c)
c.count('\n') #counts number of lines in c

# strings are immutable but can be modified
b = a.replace('string', 'longer string')
print(b)

# strings can be lists
s = 'python'
list(s)
s[:3] #this is called slicing

# \ escape character to specify special characters even a \
w = '12\\34'
print(w)
#r is raw means that the characters should be interpreted as is
s = r'this\has\no\special\characters'
print(s)

# adding strings to concatenate them
a = 'this is the first half '
b = 'and this is the second half'
print (a+b)
# Out:
# one way of writing a string
# another way
#
# This is a longer string that
# spans multiple lines
#
# one way of writing a longer string
# 12\34
# this\has\no\special\characters
# this is the first half and this is the second half

# %% [markdown]
# ### Bytes and Unicode

# %%
val = "español"
print(val)
type(val)
# convert this Unicode string to its UTF-8 bytes representation
val_utf8 = val.encode('utf-8')
print(val_utf8)
type(val_utf8)
val_utf8.decode('utf-8') #assumes you know the Unicode encoding of a bytes object

# UTF-8 is now preferred 
#but for historical reasons you may encounter data in any number of different encodings
val.encode('latin1')
val.encode('utf-16')
val.encode('utf-16le')
# Out:
# español
# b'espa\xc3\xb1ol'
# b'e\x00s\x00p\x00a\x00\xf1\x00o\x00l\x00'

# %% [markdown]
# #### None
# None is the Python null value type. If a function does not explicitly return a value, it
# implicitly returns None.
#
# None is also a common default value for function arguments.

# %% [markdown]
# ### Date and Time
# *The built-in Python datetime module provides datetime, date, and time types.*

# %%
from datetime import datetime, date, time
dt = datetime(2011, 10, 29, 20, 30, 21)
dt.day
dt.minute
dt.date() 
dt.time()

#strftime method formats a datetime as a string
dt.strftime('%m/%d/%Y %H:%M')

#Strings can be converted (parsed) into datetime objects with the strptime
datetime.strptime('20091031', '%Y%m%d')

dt.replace(minute=0, second=0) #replace minute with zero
#datetime.datetime is an immutable type, methods like these always produce new objects

#difference of two datetime objects produces a datetime.timedelta type
dt2 = datetime(2011, 11, 15, 22, 30)
delta = dt2 - dt
delta
type(delta)
#Adding a timedelta to a datetime produces a new shifted datetime
dt
dt + delta
# Out:
# datetime.datetime(2011, 11, 15, 22, 30)

# %% [markdown]
# ### Control Flow
# *Python has several built-in keywords for conditional logic, loops, and other standard
# control flow concepts found in other programming languages*

# %%
#if
x = 1
if x < 0:
    print('Its negative')
#if can be followed by multiple elif blocks 
#and a catchall else block if all of the conditions are False
elif x == 0: 
    print('Equal to zero')
elif 0 < x < 5:
    print('Positive but smaller than 5')
else:
    print('Positive and larger than or equal to 5')


#for loops
sequence = [1, 2, None, 4, None, 5]
total = 0
for value in sequence:
    if value is None:
        continue
    total += value
#A for loop can be exited altogether with the break keyword
sequence = [1, 2, 0, 4, 6, 5, 2, 1]
total_until_5 = 0
for value in sequence:
    if value == 5:
        break
    total_until_5 += value

#while loops
x = 256
total = 0
while x > 0:
    if total > 500:
        break
    total += x
    x = x // 2


#pass: the “no-op” statement in Python.
if x < 0:
    print('negative!')
elif x == 0:
    # TODO: put something smart here
    pass
else:
    print('positive!')

range(10) #sequence of evenly spaced integers
list(range(10))
list(range(0, 20, 2)) #start, end, and step can be indicated
list(range(5, 0, -1)) #they can be negative
# iterating through sequences by index
seq = [1, 2, 3, 4]
for i in range(len(seq)):
    val = seq[i]
# sums all numbers from 0 to 99,999 that are multiples of 3 or 5:
sum = 0
for i in range(100000):
    # % is the modulo operator
    if i % 3 == 0 or i % 5 == 0:
        sum += i
# Out:
# Positive but smaller than 5
# positive!

# %% [markdown]
# #### Ternary Expressions
# *combine an if-else block that produces*
# - Syntax `value = true-expr if condition else false-expr`
#
# - true-expr and false-expr can be any Python expressions

# %%
x = 5
'Non-negative' if x >= 0 else 'Negative'
