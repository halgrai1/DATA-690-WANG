# %% [markdown]
# ### Assignment 5
# **Author:** Hala Algrain
# **Date:** 3.7.2021

# %% [markdown]
# #### Instructions:
# Note: You will be using Pandas for this assignment.
#
# Upload the 2017-2018 school year file "MERGED2017_18_PP.csv" to Colab/Deepnote or any Cloud environment of your choice (you can use your local environment too) and create a Jupyter notebook to explore the dataset:

# %%
# importing pandas

import pandas as pd

# %%
# importing dataset

df = pd.read_csv("/content/MERGED2017_18_PP.csv")

df

# TOO MANY VARIABLES TO SPECIFY dtype FOR, I ADDRESS ISSUE IN SMALLER DATAFRAME
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (1729) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#         UNITID    OPEID  ...  FTFTPCTFLOAN_POOLED_SUPP SCUGFFN_POOLED
# 0       100654   100200  ...                       NaN            NaN
# 1       100663   105200  ...                       NaN            NaN
# 2       100690  2503400  ...                       NaN            NaN
# 3       100706   105500  ...                       NaN            NaN
# 4       100724   100500  ...                       NaN            NaN
# ...        ...      ...  ...                       ...            ...
# 7107  48312404   108163  ...                       NaN            NaN
# 7108  48387801  4223701  ...                       NaN            NaN
# 7109  48400201  4228101  ...                       NaN            NaN
# ...

# %% [markdown]
# #### how many colleges or rows?

# %%
# pandas shape shows (rows,columns)

df.shape
# Out:
# (7112, 1986)

# %% [markdown]
# There are 7,112 rows; thus 7,111 colleges.

# %% [markdown]
# #### how many variables or columns?

# %%
# pandas columns shows column names

df.columns
# Out:
# Index(['UNITID', 'OPEID', 'OPEID6', 'INSTNM', 'CITY', 'STABBR', 'ZIP',
#        'ACCREDAGENCY', 'INSTURL', 'NPCURL',
#        ...
#        'OMENRUP_PARTTIME_POOLED_SUPP', 'FTFTPCTPELL', 'FTFTPCTFLOAN', 'UG12MN',
#        'G12MN', 'SCUGFFN', 'POOLYRS_FTFTAIDPCT', 'FTFTPCTPELL_POOLED_SUPP',
#        'FTFTPCTFLOAN_POOLED_SUPP', 'SCUGFFN_POOLED'],
#       dtype='object', length=1986)

# %% [markdown]
# There are 1,986 columns; thus 1,985 variables.

# %% [markdown]
# ####Look at the first 5 colleges

# %%
# use pandas head to see first 5 rows

df.head(6)   #first row is column names
# Out:
#    UNITID    OPEID  ...  FTFTPCTFLOAN_POOLED_SUPP SCUGFFN_POOLED
# 0  100654   100200  ...                       NaN            NaN
# 1  100663   105200  ...                       NaN            NaN
# 2  100690  2503400  ...                       NaN            NaN
# 3  100706   105500  ...                       NaN            NaN
# 4  100724   100500  ...                       NaN            NaN
# 5  100751   105100  ...                       NaN            NaN
#
# [6 rows x 1986 columns]

# %% [markdown]
# ####Look at the last 5 colleges

# %%
# use pandas tail to see last 5 rows

df.tail() #without number it automatically shows 5
# Out:
#         UNITID    OPEID  ...  FTFTPCTFLOAN_POOLED_SUPP SCUGFFN_POOLED
# 7107  48312404   108163  ...                       NaN            NaN
# 7108  48387801  4223701  ...                       NaN            NaN
# 7109  48400201  4228101  ...                       NaN            NaN
# 7110  48778201  4221501  ...                       NaN            NaN
# 7111  49005401  4182601  ...                       NaN            NaN
#
# [5 rows x 1986 columns]

# %% [markdown]
# ####Look at a random sample of 5 colleges

# %%
# pandas sample

df.sample(5)
# Out:
#       UNITID    OPEID  ...  FTFTPCTFLOAN_POOLED_SUPP SCUGFFN_POOLED
# 5448  454759  4137200  ...                       NaN            NaN
# 5094  445258  2306804  ...                       NaN            NaN
# 6470  487454  2305808  ...                       NaN            NaN
# 2303  192165  1054900  ...                       NaN            NaN
# 5559  456542  4167200  ...                       NaN            NaN
#
# [5 rows x 1986 columns]

# %% [markdown]
# ####Since there are too many variables to explore, many of which are not interesting. Create a smaller data frame with the following 9 variables:
#
# - UNITID
# - INSTNM
# - CITY
# - STABBR
# - ZIP
# - ADM_RATE
# - UGDS
# - TUITIONFEE_IN
# - MN_EARN_WNE_P10

# %%
# creating a new smaller dataframe df2

df2 = df[["UNITID","INSTNM","CITY","STABBR","ZIP","ADM_RATE","UGDS","TUITIONFEE_IN","MN_EARN_WNE_P10"]]

df2
# Out:
#         UNITID  ... MN_EARN_WNE_P10
# 0       100654  ...             NaN
# 1       100663  ...             NaN
# 2       100690  ...             NaN
# 3       100706  ...             NaN
# 4       100724  ...             NaN
# ...        ...  ...             ...
# 7107  48312404  ...             NaN
# 7108  48387801  ...             NaN
# 7109  48400201  ...             NaN
# 7110  48778201  ...             NaN
# 7111  49005401  ...             NaN
#
# [7112 rows x 9 columns]

# %% [markdown]
# ####Find out the definition of the above 9 variables and document the definitions in the Jupyter Notebook in a Markdown cell so that the readers of your notebook will know the meaning of these variables.

# %% [markdown]
# Variable Definitions:
# - **UNITID:** Unit ID for institution
# - **INSTNM:** Institution name
# - **CITY:** City in which institution is located
# - **STABBR:** State postcode in which institution is located
# - **ZIP:** Zipcode in which institution is located
# - **ADM_RATE:** Admission Rate
# - **UGDS:** Enrollment of undergraduate certificate/degree-seeking students
# - **TUITIONFEE_IN:** In-state tuition and fees
# - **MN_EARN_WNE_P10:** Mean earnings of students working and not enrolled 10 years after entry

# %% [markdown]
# #### Explore the smaller data frame
#
# #### Look at the first 10 colleges

# %%
df2.head(11)
# Out:
#     UNITID                               INSTNM  ... TUITIONFEE_IN MN_EARN_WNE_P10
# 0   100654             Alabama A & M University  ...        9857.0             NaN
# 1   100663  University of Alabama at Birmingham  ...        8328.0             NaN
# 2   100690                   Amridge University  ...        6900.0             NaN
# 3   100706  University of Alabama in Huntsville  ...       10280.0             NaN
# 4   100724             Alabama State University  ...       11068.0             NaN
# 5   100751            The University of Alabama  ...       10780.0             NaN
# 6   100760    Central Alabama Community College  ...        4440.0             NaN
# 7   100812              Athens State University  ...           NaN             NaN
# 8   100830      Auburn University at Montgomery  ...        8020.0             NaN
# 9   100858                    Auburn University  ...       10968.0             NaN
# ...

# %% [markdown]
# #### Look at the last 10 colleges

# %%
df2.tail(10)
# Out:
#         UNITID  ... MN_EARN_WNE_P10
# 7102  48154401  ...             NaN
# 7103  48305401  ...             NaN
# 7104  48312401  ...             NaN
# 7105  48312402  ...             NaN
# 7106  48312403  ...             NaN
# 7107  48312404  ...             NaN
# 7108  48387801  ...             NaN
# 7109  48400201  ...             NaN
# 7110  48778201  ...             NaN
# 7111  49005401  ...             NaN
#
# [10 rows x 9 columns]

# %% [markdown]
# ####Look at a random sample of 10 colleges

# %%
df2.sample(10)
# Out:
#       UNITID  ... MN_EARN_WNE_P10
# 6578  489788  ...             NaN
# 6341  484978  ...             NaN
# 3129  215619  ...             NaN
# 6021  476692  ...             NaN
# 3736  235167  ...             NaN
# 730   135726  ...             NaN
# 2864  207962  ...             NaN
# 5511  455664  ...             NaN
# 60    102580  ...             NaN
# 1091  150437  ...             NaN
#
# [10 rows x 9 columns]

# %% [markdown]
# ####Find and display UMBC

# %%
# exploring type of data in pandas series

df2.dtypes
# Out:
# UNITID               int64
# INSTNM              object
# CITY                object
# STABBR              object
# ZIP                 object
# ADM_RATE           float64
# UGDS               float64
# TUITIONFEE_IN      float64
# MN_EARN_WNE_P10    float64
# dtype: object

# %%
# changing INSTNM column into string in order to do search

pd.options.mode.chained_assignment = None  # default='warn'
df2["INSTNM"] = df2["INSTNM"].astype(str)

# %%
# fuzzy search for UMBC

df2[df2['INSTNM'].str.contains("Maryland")]
# Out:
#       UNITID  ... MN_EARN_WNE_P10
# 1447  161688  ...             NaN
# 1457  162122  ...             NaN
# 1472  162830  ...             NaN
# 1475  163046  ...             NaN
# 1476  163204  ...             NaN
# 1477  163259  ...             NaN
# 1478  163268  ...             NaN
# 1479  163286  ...             NaN
# 1480  163295  ...             NaN
# 1481  163338  ...             NaN
# 1489  163578  ...             NaN
# 1493  163815  ...             NaN
# 1495  163912  ...             NaN
# 1499  164085  ...             NaN
# 4677  430184  ...             NaN
# 4770  434973  ...             NaN
#
# [16 rows x 9 columns]

# %%
#  precise search for UMBC

df2[df2["INSTNM"] == "University of Maryland-Baltimore County"]
# Out:
#       UNITID  ... MN_EARN_WNE_P10
# 1478  163268  ...             NaN
#
# [1 rows x 9 columns]

# %% [markdown]
# #### Find Univ. of Maryland College Park

# %%
#precise search for Univ. of Maryland College Park

df2[df2["INSTNM"] == "University of Maryland-College Park"]
# Out:
#       UNITID  ... MN_EARN_WNE_P10
# 1479  163286  ...             NaN
#
# [1 rows x 9 columns]

# %% [markdown]
# ####Find and display Loyola College Maryland

# %%
#precise search for Loyola College Maryland

df2[df2["INSTNM"] == "Loyola University Maryland"]
# Out:
#       UNITID                      INSTNM  ... TUITIONFEE_IN MN_EARN_WNE_P10
# 1475  163046  Loyola University Maryland  ...       47560.0             NaN
#
# [1 rows x 9 columns]

# %% [markdown]
# #### Find and display Johns Hopkins

# %%
#fuzzy search for Johns Hopkins

df2[df2['INSTNM'].str.contains("Hopkins")]
# Out:
#       UNITID                             INSTNM  ... TUITIONFEE_IN MN_EARN_WNE_P10
# 720   135294  Lindsey Hopkins Technical College  ...           NaN             NaN
# 1312  156860     Hopkinsville Community College  ...        4080.0             NaN
# 1473  162928           Johns Hopkins University  ...       52170.0             NaN
# 4630  421513          Ross College-Hopkinsville  ...           NaN             NaN
#
# [4 rows x 9 columns]

# %%
#precise search for Johns Hopkins

df2[df2["INSTNM"] == "Johns Hopkins University"]
# Out:
#       UNITID                    INSTNM  ... TUITIONFEE_IN MN_EARN_WNE_P10
# 1473  162928  Johns Hopkins University  ...       52170.0             NaN
#
# [1 rows x 9 columns]

# %% [markdown]
# #### Calculate the min, max, and average in-state tution of the above four institutions.

# %%
# pandas describe for descriptive statistics

df2.describe().loc[['min','max','std']] # use .loc to specify which stats
# Out:
#            UNITID  ADM_RATE          UGDS  TUITIONFEE_IN  MN_EARN_WNE_P10
# min  1.006540e+05  0.000000      0.000000     480.000000              NaN
# max  4.900540e+07  1.000000  77269.000000   74514.000000              NaN
# std  6.958737e+06  0.212439   5485.131878   12725.207303              NaN

# %% [markdown]
# #### Filter the smaller dataset further to only keep colleges from Maryland, Virgina, Washington DC, Delaware, and Pennsylvinia.

# %%
# creating new dataframe df3 with state subsets

df3 = df2[df2["STABBR"].isin(["MD","VA","DC","DE","PA"])]
df3
# Out:
#         UNITID  ... MN_EARN_WNE_P10
# 634     130837  ...             NaN
# 635     130873  ...             NaN
# 636     130907  ...             NaN
# 637     130934  ...             NaN
# 638     130943  ...             NaN
# ...        ...  ...             ...
# 7063  45794301  ...             NaN
# 7084  47503303  ...             NaN
# 7089  47503308  ...             NaN
# 7094  47503313  ...             NaN
# 7103  48305401  ...             NaN
#
# [690 rows x 9 columns]

# %% [markdown]
# #### Save the filtered dataset to a new file named "Five_States_Colleges.csv" for future analysis. Upload this file to your GitHub along with the notebook.

# %%
# saving a .csv

df3.to_csv(r'/content/Five_States_Colleges.csv')

# %% [markdown]
# #### Screenshot of opened output file
#
# ![Screen Shot 2021-03-07 at 8.15.32 PM.png](data:image/png;base64,...)
