# %% [markdown]
# ## Assignment 2
#
# **Author:** Hala Algrain
#
# **Date:** 2.7.2021

# %% [markdown]
# ### Requirements
# - Prompts a user to enter 10 integers.
# - Display the 10 integers back to the user at the end.
# - Calculate the following statistics from the 10 integers entered and display the results back to the user:
#     - Minimum
#     - Maximum
#     - Range
#     - Mean
#     - Variance
#     - Standard Deviation
# - If the user enters anything other than integers, remind her that only integers are allowed and let her retry.
# - *Note:* You need to detect if use makes a mistake and let the user retry without exiting the program. The previously entered valid inputs should be kept and not lost.
# Don't allow the user to enter more than 10 or less than 10 integers.

# %%
# welcome message + instructions
print("Please Enter 10 Integers to Calculate: \n Minimum, Maximum, \n Mean , Range, \n Variance, and Standard Deviation")
# Out:
# Please Enter 10 Integers to Calculate:
#  Minimum, Maximum,
#  Mean , Range,
#  Variance, and Standard Deviation

# %%
list1= []
# while loop to prompt user
# until all 10 integers are entered
# based on the length of the list
# will not stop prompting until 10
while len(list1)<10:
    try:
        user_input = int(input("Please enter an integer:")) 
    # adding each new item
    #list is not appended unless it's an integer 
        list1.append(user_input) 
        print(f"You have entered {len(list1)} integers:",user_input)
    except:
       print("This is not an integer. Please try again.")
print("The 10 integers you entered are:",list1)

#order the list with .sort()
list1.sort()
print("The MINIMUM is:", list1[0])
# to refer to the largest in the sorted list
# use the length of the list -1
print("The MAXIMUM is:", list1[len(list1)-1])

# create a new variable range
# subtract max from min
range1 = list1[len(list1)-1] - list1[0]
print ("The RANGE is:", range1)

# mean i.e. average
# create a new variable
avg = sum(list1) / len(list1)
print("The MEAN is:", avg)

#variance
var = sum((x-avg)**2 for x in list1) / len(list1)
print("The VARIANCE is:", var)

# standard deviation
# square root of var
std = var**0.5
print("The STANDARD DEVIATION:", std)
# Out:
# You have entered 1 integers: 5
# You have entered 2 integers: 6
# This is not an integer. Please try again.
# You have entered 3 integers: 7
# This is not an integer. Please try again.
# This is not an integer. Please try again.
# You have entered 4 integers: 6
# You have entered 5 integers: 8
# You have entered 6 integers: 9
# You have entered 7 integers: 11
# This is not an integer. Please try again.
# You have entered 8 integers: 5
# You have entered 9 integers: 6
# You have entered 10 integers: 7
# The 10 integers you entered are: [5, 6, 7, 6, 8, 9, 11, 5, 6, 7]
# The MINIMUM is: 5
# The MAXIMUM is: 11
# The RANGE is: 6
# The MEAN is: 7.0
# The VARIANCE is: 3.2
# The STANDARD DEVIATION: 1.7888543819998317

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=27eb9605-46d8-49f9-aeb4-8c1cb5079554' target="_blank">
# <img style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
